# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# In the US, all high school students are required to take college entrance tests before they submit their application to any college. The SAT and ACT are the most popular college entrance test administered in the US.
#
# The question is how might we increase the participation rate among high school students in the United States in taking the SAT test for college admissions so that I can make recommendation to the College Board that administers the SAT test.

# %% [markdown]
# ## Executive Summary
#
# In this project, I will be examine the data for SAT and ACT in 2017 and 2018. The data includes participation rates, mean score of each subject, and total/composite scores which are organized at the state level in alphabet order.
#
# Throughout this data analysis exploration, I will perform data preparation, data visualization and analyzing the SAT and ACT participation rates as well as the scoring across the state in the US. Then, I will identify trend in the data and combine with my research to develop potential solutions to the problem statement.
#
# __Data source:__
# - [SAT 2017 Data](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT 2017 Data](https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf)
# - [SAT 2018 Data](https://reports.collegeboard.org/archive/sat-suite-program-results/2018/state-results)
# - [ACT 2018 Data](https://nces.ed.gov/programs/digest/d18/tables/dt18_226.60.asp)
#
# ### Contents:
# - [2017 Data Import & Cleaning](#2017-Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
# read csv file
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %%
# read csv file
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
display(sat_2017.shape) # check the number of rows and columns of the data
display(sat_2017.head(10)) # display the top 10 of the data
# Out:
# (51, 5)
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# ...

# %%
display(act_2017.shape) # check the number of rows and columns of the data
display(act_2017.head(10)) # display the top 10 of the data
# Out:
# (52, 7)
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# Dataframes above are the data being imported from the excel file in csv format.

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# ## SAT
#
# The SAT is a standardized test widely used in the United States for the evaluation of college admission. The SAT dataframe consists of 5 attributes. It shows us the information about __Participation__, __Evidence-Based Reading and Writing__ test, __Math__ test and __Total__ column that are gathered from 51 states of the United States under __State__ column in alphabetical order.
#
# The __Participation__ column shows test-taking candidates as a percentage of all 2016 high school graduates. State percentages were calculated based on the number of high school graduates in each state.
#
# The __Evidence-Based Reading and Writing__ and __Math__ columns show the mean score of each test of each state and the __Total__ column is the sum of the mean score of the 2 tests. The __Evidence-Based Reading and Writing__, __Math__ and __Total__ scores provided have been rounded up to the nearest integer whole number.
#
# ## ACT
#
# The ACT is a standardized test widely used in the United States for the evaluation of college admission. The ACT dataframe consists of 7 attributes. It shows us the information about __Participation__, __English__ test, __Math__ test, __Reading__ test, __Science__ test and __Composite__ column gathered from 51 states of the United States under __State__ column in alphabetical order.
#
# The __Participation__ column shows test-taking candidates as a percentage of all 2016 high school graduates. State percentages were calculated based on the number of high school graduates in each state.
#
# The __English__, __Math__, __Reading__ and __Science__ columns are the mean score of each test and the __Composite__ column is the mean score of the 4 tests. The __English__, __Math__, __Reading__, __Science__ and __Composite__ scores provided have been rounded up to the nearest one decimal real number.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# The data displayed so far looks complete because no values or numbers are missing in any of the attributes' columns for both dataframes. I will review the data more thoroughly in the next process when I massage the data to ensure the data has no issue for further analysis.
#
# ACT dataframe shows 52 rows of results whereby the United States only has 51 states. Thus, the row 0 of ACT dataframe, *__National__* under __State__ column has to be removed.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# ## SAT

# %%
# check the descriptive statistics
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# From the descriptive statistics table shown above, the minimum and maximum possible values of the 2 tests are as follows:
#
# | __Description__ | __Min Value__ | __Max Value__
# |:---|:---:|:---:
# |Evidence-Based Reading and Writing |482.00 |644.00
# |Math |52.00 |651.00

# %% [markdown]
# ## ACT

# %%
# check the dataframe descriptive statistics
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# From the descriptive statistics table shown above, the minimum and maximum possible values of the 4 tests are as follows:
#
# | __Description__ | __Min Value__ | __Max Value__
# |:---|:---:|:---:
# |English |16.30 |25.50
# |Math |18.00 |25.30
# |Reading |18.10 |26.00
# |Science |2.30 |24.90

# %% [markdown]
# ----------------------------------------------------------------------

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %% [markdown]
# ## SAT

# %%
# check the dataframe descriptive statistics
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# check the Math mean value that less than 200
sat_2017.loc[sat_2017['Math']<200,['State','Math']]
# Out:
#        State  Math
# 20  Maryland    52

# %%
# replace the error data and update the dataframe
sat_2017['Math'].replace({52:524}, inplace = True);
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# According to the SAT's College Board, scaled scores for both tests are between 200 to 800 but the minimum result in the statistic desciptive table shows that it is less than 200. So I did a cross-check of the dataframe and noticed that the mean score of Math at row 20, Maryland state is *__52__*. I referred back to the data sources that I obtained from the 2017 SAT Suite of Assessments Annual Report and updated the information.
#
# The updated minimum and maximum possible values of the 2 tests are as follows:
#
# | __Description__ | __Min Value__ | __Max Value__
# |:---|:---:|:---:
# |Evidence-Based Reading and Writing |482.00 |644.00
# |Math |468.00 |651.00

# %% [markdown]
# ## ACT

# %%
# check the dataframe descriptive statistics
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
# check the Science mean value that less than 15
act_2017.loc[act_2017['Science']<15,['State','Science']]
# Out:
#        State  Science
# 21  Maryland      2.3

# %%
# replace the error data and update the dataframe
act_2017['Science'].replace({2.3:23.2}, inplace = True);
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.442308
# std     2.332132   1.963602   2.048672   1.723351
# min    16.300000  18.000000  18.100000  18.200000
# 25%    19.000000  19.400000  20.475000  19.975000
# 50%    20.550000  20.900000  21.700000  21.300000
# 75%    23.300000  23.100000  24.125000  23.200000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# According to ACT, the scaled scores for the 4 tests is in the range from 1 to 36. However, the data seems  to be odd because the minimum score of Science test is very low compare to the other 3 tests. I ran a search for the Science test and noticed that the mean score of Science at row 21, Maryland state is *__2.3__*. I then compared the data with the 2017 Average ACT Scores and updated the information.
#
# The updated mininum and maximum possible values of the 4 tests are as follows:
#
# | __Description__ | __Min Value__ | __Max Value__
# |:---|:---:|:---:
# |English |16.30 |25.50
# |Math |18.00 |25.30
# |Reading |18.10 |26.00
# |Science |18.20 |24.90

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %% [markdown]
# ## SAT

# %%
# check the data types
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# ## ACT

# %%
# check the data types
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# From the dataframe summaries shown above, I noticed that the data type of __Participation__ column for both ACT and SAT dataframe is in *__object__* data type. It is recommended to convert the data type to a numerical format such as float data type, which will enable us to do mathematical calculation or generate graphs or charts.
#
# I also noticed that under the ACT dataframe, the data type of __Composite__ column is in *__object__* data type instead of numerical format such as float data type. I first tried to convert the object data type to float data type but it returned the error message. So I did a debug to find the error data and noticed a mixed value data, *__'20.2x'__* , in row 51. Thus, I replaced the data and converted the whole data under __Composite__ column to a float data type.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
'''
convert percentage object data type of sat_2017_df['Participation']
and act_2017_df['Participation'] to float data type
''' 
def participation_to_float(percentage_string):
    return float(str(percentage_string).strip('%'))/100

sat_2017['Participation'] = sat_2017['Participation'].apply(lambda x: participation_to_float(x))
act_2017['Participation'] = act_2017['Participation'].apply(lambda x: participation_to_float(x))

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %% [markdown]
# ## SAT

# %%
# check the data types
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## ACT

# %%
# check the data types
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# identify which row of the data has mixed value data
for i, item in enumerate(act_2017['Composite']):
    try:
        float(item)
    except ValueError:
        print('ERROR at index {}: {!r}'.format(i, item))
# Out:
# ERROR at index 51: '20.2x'

# %%
# replace the error data and update the dataframe
act_2017.replace(to_replace = '20.2x', value='20.2', inplace = True)

# %%
# convert act_2017_df['Composite'] to float data type and it success
act_2017['Composite'] = act_2017['Composite'].astype(float)

# %% [markdown]
# ## SAT

# %%
'''
check the dataframe to ensure the sat_2017_df['Participation']
has converted. Everything looks good and dataframe is updated.
'''
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %% [markdown]
# ## ACT

# %%
'''
check the dataframe to ensure the act_2017_df['Participation']
has converted. Everything looks good and dataframe is updated.
'''
act_2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %% [markdown]
# ## SAT

# %%
# ensure the data types are correct and everything looks good.
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# ## ACT

# %%
# ensure the data types are correct and everything looks good.
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %% [markdown]
# ## SAT Columns' Renamed

# %%
# rename the dataframe's header and update the dataframe
sat_2017.rename(columns={'State':'us_state',
                         'Participation':'sat_part_17',
                         'Evidence-Based Reading and Writing':'sat_erw_17',
                         'Math':'sat_math_17',
                         'Total':'sat_total_17'},inplace=True)

# %%
# check the updated dataframe's header
sat_2017.head()
# Out:
#      us_state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17
# 0     Alabama         0.05         593          572          1165
# 1      Alaska         0.38         547          533          1080
# 2     Arizona         0.30         563          553          1116
# 3    Arkansas         0.03         614          594          1208
# 4  California         0.53         531          524          1055

# %% [markdown]
# ## ACT Columns' Renamed

# %%
# rename the dataframe's header and update the dataframe
act_2017.rename(columns={'State':'us_state',
                         'Participation':'act_part_17',
                         'English':'act_eng_17',
                         'Math':'act_math_17',
                         'Reading':'act_read_17',
                         'Science':'act_sci_17',
                         'Composite':'act_comp_17'},inplace=True)

# %%
# check the updated dataframe's header
act_2017.head()
# Out:
#    us_state  act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  \
# 0  National         0.60        20.3         20.7         21.4        21.0
# 1   Alabama         1.00        18.9         18.4         19.7        19.4
# 2    Alaska         0.65        18.7         19.8         20.4        19.9
# 3   Arizona         0.62        18.6         19.8         20.1        19.8
# 4  Arkansas         1.00        18.9         19.0         19.7        19.5
#
#    act_comp_17
# 0         21.0
# 1         19.2
# 2         19.8
# 3         19.7
# 4         19.4

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |__Feature__|__Type__|__Dataset__|__Description__|
# |---:|:---:|:---:|---:|
# |us_state|*object*|SAT/ACT|51 states in the United States|
# |sat_part_17|*float*|SAT|Statewide SAT participation rate by percentage in 2017|
# |sat_erw_17|*integer*|SAT|SAT 2017 *Evidence-Based Reading and Writing* test mean score(200-800) of each state|
# |sat_math_17|*integer*|SAT|SAT 2017 *Math* test mean score(200-800) of each state|
# |sat_total_17|*integer*|SAT|SAT 2017 *Total* is the sum of both test mean score(400-1600) of each state|
# |act_part_17|*float*|ACT|Statewide ACT participation rate by percentage in 2017|
# |act_eng_17|*float*|ACT|ACT 2017 *English* test mean score(1-36) of each state|
# |act_math_17|*float*|ACT|ACT 2017 *Math* test mean score(1-36) of each state|
# |act_read_17|*float*|ACT|ACT 2017 *Reading* test mean score(1-36) of each state|
# |act_sci_17|*float*|ACT|ACT 2017 *Science* test mean score(1-36) of each state|
# |act_comp_17|*float*|ACT|ACT 2017 *Composite* is the mean score(1-36) of the 4 tests of each state|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
# remove the extra row
act_2017.drop(0, axis=0, inplace=True)

# %%
# check the updated dataframe and is correct
act_2017.head()
# Out:
#      us_state  act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  \
# 1     Alabama         1.00        18.9         18.4         19.7        19.4
# 2      Alaska         0.65        18.7         19.8         20.4        19.9
# 3     Arizona         0.62        18.6         19.8         20.1        19.8
# 4    Arkansas         1.00        18.9         19.0         19.7        19.5
# 5  California         0.31        22.5         22.7         23.1        22.2
#
#    act_comp_17
# 1         19.2
# 2         19.8
# 3         19.7
# 4         19.4
# 5         22.8

# %%
# re-arrange the index number
act_2017.index = np.arange(0,len(act_2017))
act_2017.head()
# Out:
#      us_state  act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  \
# 0     Alabama         1.00        18.9         18.4         19.7        19.4
# 1      Alaska         0.65        18.7         19.8         20.4        19.9
# 2     Arizona         0.62        18.6         19.8         20.1        19.8
# 3    Arkansas         1.00        18.9         19.0         19.7        19.5
# 4  California         0.31        22.5         22.7         23.1        22.2
#
#    act_comp_17
# 0         19.2
# 1         19.8
# 2         19.7
# 3         19.4
# 4         22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# combine both sat_2017_df and act_2017_df dataframes
combined_2017 = pd.merge(sat_2017, act_2017, how='outer', on='us_state')

# %%
# review the combined dataframe
combined_2017.head()
# Out:
#      us_state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  \
# 0     Alabama         0.05         593          572          1165
# 1      Alaska         0.38         547          533          1080
# 2     Arizona         0.30         563          553          1116
# 3    Arkansas         0.03         614          594          1208
# 4  California         0.53         531          524          1055
#
#    act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  act_comp_17
# 0         1.00        18.9         18.4         19.7        19.4         19.2
# 1         0.65        18.7         19.8         20.4        19.9         19.8
# 2         0.62        18.6         19.8         20.1        19.8         19.7
# 3         1.00        18.9         19.0         19.7        19.5         19.4
# 4         0.31        22.5         22.7         23.1        22.2         22.8

# %%
# ensure the data types are correct
combined_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   us_state      51 non-null     object
#  1   sat_part_17   51 non-null     float64
#  2   sat_erw_17    51 non-null     int64
#  3   sat_math_17   51 non-null     int64
#  4   sat_total_17  51 non-null     int64
#  5   act_part_17   51 non-null     float64
#  6   act_eng_17    51 non-null     float64
#  7   act_math_17   51 non-null     float64
#  8   act_read_17   51 non-null     float64
#  9   act_sci_17    51 non-null     float64
#  10  act_comp_17   51 non-null     float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 4.8+ KB

# %%
'''
check the data to ensure that no odd result 
of the min. or max values of test mean score.
''' 
combined_2017.describe()
# Out:
#        sat_part_17  sat_erw_17  sat_math_17  sat_total_17  act_part_17  \
# count    51.000000   51.000000    51.000000     51.000000    51.000000
# mean      0.398039  569.117647   556.882353   1126.098039     0.652549
# std       0.352766   45.666901    47.121395     92.494812     0.321408
# min       0.020000  482.000000   468.000000    950.000000     0.080000
# 25%       0.040000  533.500000   523.500000   1055.500000     0.310000
# 50%       0.380000  559.000000   548.000000   1107.000000     0.690000
# 75%       0.660000  613.000000   599.000000   1212.000000     1.000000
# max       1.000000  644.000000   651.000000   1295.000000     1.000000
#
#        act_eng_17  act_math_17  act_read_17  act_sci_17  act_comp_17
# count   51.000000    51.000000    51.000000   51.000000    51.000000
# mean    20.931373    21.182353    22.013725   21.450980    21.519608
# std      2.353677     1.981989     2.067271    1.739353     2.020695
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
# save the combined_2017 to csv file
combined_2017.to_csv('../data/combined_2017.csv', index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %% [markdown]
# For the preparation of the CSV file, I have collected the data sources for SAT_2018 from College Board and ACT_2018 and combined both data into a single CSV file.

# %%
# import combined_2018.csv file
combined_2018 = pd.read_csv('../data/combined_2018.csv')

# %%
display(combined_2018.head()) # review the dataframe
display(combined_2018.info()) # check the data types
# Out:
#      us_state sat_part_18  sat_erw_18  sat_math_18  sat_total_18 act_part_18  \
# 0     Alabama          6%         595          571          1166        100%
# 1      Alaska         43%         562          544          1106         33%
# 2     Arizona         29%         577          572          1149         66%
# 3    Arkansas          5%         592          576          1169        100%
# 4  California         60%         540          536          1076         27%
#
#    act_eng_18  act_math_18  act_read_18  act_sci_18  act_comp_18
# 0        18.9         18.3         19.6        19.0         19.1
# 1        19.8         20.6         21.6        20.7         20.8
# 2        18.2         19.4         19.5        19.2         19.2
# 3        19.1         18.9         19.7        19.4         19.4
# 4        22.5         22.5         23.0        22.1         22.7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
# ...

# %%
'''
convert percentage object data type of sat_2018_participation
and act_2018_participation to float data type
'''
combined_2018['sat_part_18'] = combined_2018['sat_part_18'].apply(lambda x: participation_to_float(x))
combined_2018['act_part_18'] = combined_2018['act_part_18'].apply(lambda x: participation_to_float(x))

# %%
# review the dataframe after convertion
combined_2018.head()
# Out:
#      us_state  sat_part_18  sat_erw_18  sat_math_18  sat_total_18  \
# 0     Alabama         0.06         595          571          1166
# 1      Alaska         0.43         562          544          1106
# 2     Arizona         0.29         577          572          1149
# 3    Arkansas         0.05         592          576          1169
# 4  California         0.60         540          536          1076
#
#    act_part_18  act_eng_18  act_math_18  act_read_18  act_sci_18  act_comp_18
# 0         1.00        18.9         18.3         19.6        19.0         19.1
# 1         0.33        19.8         20.6         21.6        20.7         20.8
# 2         0.66        18.2         19.4         19.5        19.2         19.2
# 3         1.00        19.1         18.9         19.7        19.4         19.4
# 4         0.27        22.5         22.5         23.0        22.1         22.7

# %%
# ensure the data types are correct
combined_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   us_state      51 non-null     object
#  1   sat_part_18   51 non-null     float64
#  2   sat_erw_18    51 non-null     int64
#  3   sat_math_18   51 non-null     int64
#  4   sat_total_18  51 non-null     int64
#  5   act_part_18   51 non-null     float64
#  6   act_eng_18    51 non-null     float64
#  7   act_math_18   51 non-null     float64
#  8   act_read_18   51 non-null     float64
#  9   act_sci_18    51 non-null     float64
#  10  act_comp_18   51 non-null     float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 4.5+ KB

# %%
'''
check the data to ensure that no odd result 
of the min. or max values of test mean score.
''' 
combined_2018.describe()
# Out:
#        sat_part_18  sat_erw_18  sat_math_18  sat_total_18  act_part_18  \
# count    51.000000   51.000000    51.000000     51.000000    51.000000
# mean      0.466275  567.294118   557.254902   1124.666667     0.616471
# std       0.380142   45.317676    48.887562     93.868561     0.340810
# min       0.020000  497.000000   480.000000    977.000000     0.070000
# 25%       0.045000  535.000000   521.500000   1062.500000     0.285000
# 50%       0.520000  552.000000   547.000000   1099.000000     0.660000
# 75%       0.795000  616.500000   600.500000   1220.000000     1.000000
# max       1.000000  643.000000   655.000000   1298.000000     1.000000
#
#        act_eng_18  act_math_18  act_read_18  act_sci_18  act_comp_18
# count   51.000000    51.000000    51.000000   51.000000    51.000000
# mean    20.988235    21.125490    22.015686   21.345098    21.486275
# std      2.446356     2.035765     2.167245    1.870114     2.106278
# ...

# %% [markdown]
# |__Feature__|__Type__|__Dataset__|__Description__|
# |---:|:---:|:---:|---:|
# |us_state|*object*|SAT/ACT|51 states in the United States|
# |sat_part_18|*float*|SAT|Statewide SAT participation rate by percentage in 2018|
# |sat_erw_18|*integer*|SAT|SAT 2018 *Evidence-Based Reading and Writing* test mean score(200-800) of each state|
# |sat_math_18|*integer*|SAT|SAT 2018 *Math* test mean score(200-800) of each state|
# |sat_total_18|*integer*|SAT|SAT 2018 *Total* is the sum of both test mean score(400-1600) of each state|
# |act_part_18|*float*|ACT|Statewide ACT participation rate by percentage in 2018|
# |act_eng_18|*float*|ACT|ACT 2018 *English* test mean score(1-36) of each state|
# |act_math_18|*float*|ACT|ACT 2018 *Math* test mean score(1-36) of each state|
# |act_read_18|*float*|ACT|ACT 2018 *Reading* test mean score(1-36) of each state|
# |act_sci_18|*float*|ACT|ACT 2018 *Science* test mean score(1-36) of each state|
# |act_comp_18|*float*|ACT|ACT 2018 *Composite* is the mean score(1-36) of the 4 tests of each state|

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# combine both combined_2017 and combined_2018 dataframes
final = pd.merge(combined_2017, combined_2018, how='outer', on='us_state')

# %%
# review the dataframe
final.head()
# Out:
#      us_state  sat_part_17  sat_erw_17  sat_math_17  sat_total_17  \
# 0     Alabama         0.05         593          572          1165
# 1      Alaska         0.38         547          533          1080
# 2     Arizona         0.30         563          553          1116
# 3    Arkansas         0.03         614          594          1208
# 4  California         0.53         531          524          1055
#
#    act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  ...  \
# 0         1.00        18.9         18.4         19.7        19.4  ...
# 1         0.65        18.7         19.8         20.4        19.9  ...
# 2         0.62        18.6         19.8         20.1        19.8  ...
# 3         1.00        18.9         19.0         19.7        19.5  ...
# 4         0.31        22.5         22.7         23.1        22.2  ...
#
#    sat_part_18  sat_erw_18  sat_math_18  sat_total_18  act_part_18  \
# 0         0.06         595          571          1166         1.00
# ...

# %%
# save the final_combined to csv file
final.to_csv('../data/final.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
# transpose the dataframe descriptive statistics
final.describe().transpose()
# Out:
#               count         mean        std     min       25%      50%  \
# sat_part_17    51.0     0.398039   0.352766    0.02     0.040     0.38
# sat_erw_17     51.0   569.117647  45.666901  482.00   533.500   559.00
# sat_math_17    51.0   556.882353  47.121395  468.00   523.500   548.00
# sat_total_17   51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# act_part_17    51.0     0.652549   0.321408    0.08     0.310     0.69
# act_eng_17     51.0    20.931373   2.353677   16.30    19.000    20.70
# act_math_17    51.0    21.182353   1.981989   18.00    19.400    20.90
# act_read_17    51.0    22.013725   2.067271   18.10    20.450    21.80
# act_sci_17     51.0    21.450980   1.739353   18.20    19.950    21.30
# act_comp_17    51.0    21.519608   2.020695   17.80    19.800    21.40
# sat_part_18    51.0     0.466275   0.380142    0.02     0.045     0.52
# sat_erw_18     51.0   567.294118  45.317676  497.00   535.000   552.00
# ...

# %% [markdown]
# From the descriptive table above, it shows us the count, mean, sample standard deviation, min, 25%, 50%, 75% and max of individual data whereby it has to be float or interger data type.

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
import math

def std_dev(data):
    n = len(data)
    mean = sum(data)/n
    sd = 0
    for num in data:
        sd += ((float(num) - mean)**2)/n
    sd = math.sqrt(sd)
    return sd

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final_population_sd = {i: round(std_dev(final[i]), 2) for i in final.columns[1:]}
final_population_sd
# Out:
# {'sat_part_17': 0.35,
#  'sat_erw_17': 45.22,
#  'sat_math_17': 46.66,
#  'sat_total_17': 91.58,
#  'act_part_17': 0.32,
#  'act_eng_17': 2.33,
#  'act_math_17': 1.96,
#  'act_read_17': 2.05,
#  'act_sci_17': 1.72,
#  'act_comp_17': 2.0,
#  'sat_part_18': 0.38,
#  'sat_erw_18': 44.87,
#  'sat_math_18': 48.41,
#  'sat_total_18': 92.94,
#  'act_part_18': 0.34,
#  'act_eng_18': 2.42,
#  'act_math_18': 2.02,
#  'act_read_18': 2.15,
#  'act_sci_18': 1.85,
#  'act_comp_18': 2.09}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
# generate standard deviation using numpy
np.std(final)
# Out:
# sat_part_17      0.349291
# sat_erw_17      45.216970
# sat_math_17     46.657134
# sat_total_17    91.583511
# act_part_17      0.318242
# act_eng_17       2.330488
# act_math_17      1.962462
# act_read_17      2.046903
# act_sci_17       1.722216
# act_comp_17      2.000786
# sat_part_18      0.376397
# sat_erw_18      44.871186
# sat_math_18     48.405899
# sat_total_18    92.943725
# act_part_18      0.337452
# act_eng_18       2.422254
# act_math_18      2.015707
# act_read_18      2.145892
# act_sci_18       1.851689
# act_comp_18      2.085526
# dtype: float64

# %% [markdown]
# The answer for standard deviation using Numpy's `std` method is similar with the answer using manually calculated standard deviation, however both's answers are different from the pandas's describe method.
#
# Numpy's std method and manually calculated standard deviation perform the calculation based on the population standard deviation. The population standard deviation is using the size of the population to find the standard deviation.
#
# Standard deviation from pandas's `describe` method perform the calculation based on the sample standard deviation, whereby it uses the sample as the size of the whole population and it has greater variability. Thus, the value of sample standard deviation is greather than the population standard deviation.
#
# For the current project, we will use the sample standard deviation because we do not want to generalize the finding to the population.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ## Lowest and Highest SAT States Participation Rate in 2017

# %%
# lowest SAT states participation rate in 2017
final.sort_values('sat_part_17')[['us_state','sat_part_17']].head(20)
# Out:
#         us_state  sat_part_17
# 34  North Dakota         0.02
# 24   Mississippi         0.02
# 15          Iowa         0.02
# 25      Missouri         0.03
# 44          Utah         0.03
# 41  South Dakota         0.03
# 27      Nebraska         0.03
# 49     Wisconsin         0.03
# 23     Minnesota         0.03
# 50       Wyoming         0.03
# 3       Arkansas         0.03
# 16        Kansas         0.04
# 17      Kentucky         0.04
# 18     Louisiana         0.04
# 0        Alabama         0.05
# 42     Tennessee         0.05
# 36      Oklahoma         0.07
# 13      Illinois         0.09
# 26       Montana         0.10
# 5       Colorado         0.11

# %%
# highest SAT states participation rate in 2017
final.sort_values('sat_part_17',ascending=False)[['us_state','sat_part_17']].head(10)
# Out:
#                 us_state  sat_part_17
# 8   District of Columbia         1.00
# 22              Michigan         1.00
# 6            Connecticut         1.00
# 7               Delaware         1.00
# 29         New Hampshire         0.96
# 19                 Maine         0.95
# 12                 Idaho         0.93
# 9                Florida         0.83
# 21         Massachusetts         0.76
# 39          Rhode Island         0.71

# %% [markdown]
# For the SAT participation rate in 2017, we can see that the District of Columbia, Michigan, Connecticut and Delaware have 100% participation rate, but there are around 18 states that have less than 10% participation rates and North Dakota, Mississippi and Iowa have the lowest participation rate at only 2%.

# %% [markdown]
# ## Lowest and Highest SAT States Participation Rate in 2018

# %%
# lowest SAT states participation rate in 2018
final.sort_values('sat_part_18')[['us_state','sat_part_18']].head(10)
# Out:
#         us_state  sat_part_18
# 34  North Dakota         0.02
# 50       Wyoming         0.03
# 41  South Dakota         0.03
# 27      Nebraska         0.03
# 49     Wisconsin         0.03
# 24   Mississippi         0.03
# 15          Iowa         0.03
# 44          Utah         0.04
# 23     Minnesota         0.04
# 18     Louisiana         0.04

# %%
# highest SAT states participation rate in 2018
final.sort_values('sat_part_18',ascending=False)[['sat_part_18']].head(10)
# Out:
#     sat_part_18
# 5          1.00
# 6          1.00
# 7          1.00
# 22         1.00
# 12         1.00
# 19         0.99
# 13         0.99
# 39         0.97
# 9          0.97
# 29         0.96

# %% [markdown]
# For the SAT in 2018, Colorado's and Idaho's participation rates have increased to 100% while Michigan, Connecticut and Delware still have 100% participation rate. However, there are 17 states with participation rates less than 10% and North Dakota still has the lowest participation rate at 2%.

# %% [markdown]
# ## Lowest and Highest ACT States Participation Rate in 2017

# %%
# lowest ACT states participation rate in 2017
final.sort_values('act_part_17')[['us_state','act_part_17']].head()
# Out:
#          us_state  act_part_17
# 19          Maine         0.08
# 29  New Hampshire         0.18
# 7        Delaware         0.18
# 39   Rhode Island         0.21
# 38   Pennsylvania         0.23

# %%
# highest ACT states participation rate in 2017
final.sort_values('act_part_17',ascending=False)[['us_state','act_part_17']].head(20)
# Out:
#           us_state  act_part_17
# 0          Alabama         1.00
# 17        Kentucky         1.00
# 49       Wisconsin         1.00
# 44            Utah         1.00
# 42       Tennessee         1.00
# 40  South Carolina         1.00
# 36        Oklahoma         1.00
# 33  North Carolina         1.00
# 28          Nevada         1.00
# 26         Montana         1.00
# 24     Mississippi         1.00
# 23       Minnesota         1.00
# 18       Louisiana         1.00
# 25        Missouri         1.00
# 50         Wyoming         1.00
# 5         Colorado         1.00
# 3         Arkansas         1.00
# 34    North Dakota         0.98
# 13        Illinois         0.93
# 11          Hawaii         0.90

# %% [markdown]
# For ACT participation rate in 2017, you can see that there are 17 states have 100% participation rate for ACT in 2017, which is a third of the US total states. Maine at 8% is the only one state with a participation rate less than 10%, followed by New Hampshire and Delaware at 18% each.

# %% [markdown]
# ## Lowest and Highest ACT States Participation Rate in 2018

# %%
# lowest ACT states participation rate in 2018
final.sort_values('act_part_18')[['us_state','act_part_18']].head()
# Out:
#          us_state  act_part_18
# 19          Maine         0.07
# 39   Rhode Island         0.15
# 29  New Hampshire         0.16
# 7        Delaware         0.17
# 38   Pennsylvania         0.20

# %%
# highest ACT states participation rate in 2018
final.sort_values('act_part_18',ascending=False)[['us_state','act_part_18']].head(20)
# Out:
#           us_state  act_part_18
# 0          Alabama         1.00
# 17        Kentucky         1.00
# 49       Wisconsin         1.00
# 44            Utah         1.00
# 42       Tennessee         1.00
# 40  South Carolina         1.00
# 36        Oklahoma         1.00
# 35            Ohio         1.00
# 33  North Carolina         1.00
# 28          Nevada         1.00
# 27        Nebraska         1.00
# 26         Montana         1.00
# 24     Mississippi         1.00
# 18       Louisiana         1.00
# 25        Missouri         1.00
# 50         Wyoming         1.00
# 3         Arkansas         1.00
# 23       Minnesota         0.99
# 34    North Dakota         0.98
# 11          Hawaii         0.89

# %% [markdown]
# For 2018 SAT participation rate, there are 17 states that have 100% participation rates, while the lowest participation rate is Maine (7%), Rhode Island (15%), New Hampshire (16%) and Delaware (17%).
#
# When we look at the data in 2018, we can see that the ACT has 17 states with 100% participation rate compared to the SAT that only has 5 states with 100% participation rate. Meanwhile, the ACT has only 1 state with less than 10% participation rate while SAT has 16 states.
#
# It is obvious that the ACT is the preferred test compared to the SAT. This could be because the test is mandated by the state authority or the individual preference beacuse of the nature of the test.

# %% [markdown]
# ## Lowest and Highest SAT Total of Each State in 2017

# %%
# lowest SAT mean total of each state in 2017
final.sort_values('sat_total_17')[['us_state','sat_total_17']].head()
# Out:
#                 us_state  sat_total_17
# 8   District of Columbia           950
# 7               Delaware           996
# 12                 Idaho          1005
# 22              Michigan          1005
# 19                 Maine          1012

# %%
# highest SAT mean total of each state in 2017
final.sort_values('sat_total_17',ascending=False)[['us_state','sat_total_17']].head()
# Out:
#      us_state  sat_total_17
# 23  Minnesota          1295
# 49  Wisconsin          1291
# 15       Iowa          1275
# 25   Missouri          1271
# 16     Kansas          1260

# %% [markdown]
# ## Lowest and Highest SAT Total of Each State in 2018

# %%
# lowest SAT mean total of each state in 2018
final.sort_values('sat_total_18')[['us_state','sat_total_18']].head()
# Out:
#                 us_state  sat_total_18
# 8   District of Columbia           977
# 7               Delaware           998
# 48         West Virginia           999
# 12                 Idaho          1001
# 22              Michigan          1011

# %%
# highest SAT mean total of each state in 2018
final.sort_values('sat_total_18',ascending=False)[['us_state','sat_total_18']].head()
# Out:
#         us_state  sat_total_18
# 23     Minnesota          1298
# 49     Wisconsin          1294
# 34  North Dakota          1283
# 15          Iowa          1265
# 16        Kansas          1265

# %% [markdown]
# ## Lowest and Highest ACT Composition of Each State in 2017

# %%
# lowest ACT composition of each state in 2017
final.sort_values('act_comp_17')[['us_state','act_comp_17']].head()
# Out:
#           us_state  act_comp_17
# 28          Nevada         17.8
# 24     Mississippi         18.6
# 40  South Carolina         18.7
# 11          Hawaii         19.0
# 33  North Carolina         19.1

# %%
# highest ACT composition of each state in 2017
final.sort_values('act_comp_17',ascending=False)[['us_state','act_comp_17']].head()
# Out:
#                 us_state  act_comp_17
# 29         New Hampshire         25.5
# 21         Massachusetts         25.4
# 6            Connecticut         25.2
# 19                 Maine         24.3
# 8   District of Columbia         24.2

# %% [markdown]
# ## Lowest and Highest ACT Composition of Each State in 2018

# %%
# lowest ACT composition of each state in 2018
final.sort_values('act_comp_18')[['us_state','act_comp_18']].head()
# Out:
#           us_state  act_comp_18
# 28          Nevada         17.7
# 40  South Carolina         18.3
# 24     Mississippi         18.6
# 11          Hawaii         18.9
# 0          Alabama         19.1

# %%
# highest ACT composition of each state in 2018
final.sort_values('act_comp_18',ascending=False)[['us_state','act_comp_18']].head()
# Out:
#          us_state  act_comp_18
# 6     Connecticut         25.6
# 21  Massachusetts         25.5
# 29  New Hampshire         25.1
# 32       New York         24.5
# 22       Michigan         24.4

# %% [markdown]
# The lowest and highest of the SAT and the ACT test's Total and Composition scores in both years is biased state by state. This is because the participation rate varies across each state. A lower participation rate could have higher mean score because of highly motivated students, or a higher participation rate could have a low mean score beacuse of the wider range of student ability.

# %% [markdown]
# ## US states with 100% participation rate on a given test that have a rate changed between 2017 and 2018

# %%
# SAT state's participation between 2017 & 2018 in descending manner
sat_title = ['us_state','sat_part_17','sat_part_18']
final.sort_values('sat_part_17', ascending=False)[sat_title].head(10)
# Out:
#                 us_state  sat_part_17  sat_part_18
# 8   District of Columbia         1.00         0.92
# 22              Michigan         1.00         1.00
# 6            Connecticut         1.00         1.00
# 7               Delaware         1.00         1.00
# 29         New Hampshire         0.96         0.96
# 19                 Maine         0.95         0.99
# 12                 Idaho         0.93         1.00
# 9                Florida         0.83         0.97
# 21         Massachusetts         0.76         0.80
# 39          Rhode Island         0.71         0.97

# %%
# SAT states participation rate between 2017 & 2018 in descending manner
sat_title = ['us_state','sat_part_17','sat_part_18']
final.sort_values('sat_part_18', ascending=False)[sat_title].head(10)
# Out:
#          us_state  sat_part_17  sat_part_18
# 5        Colorado         0.11         1.00
# 6     Connecticut         1.00         1.00
# 7        Delaware         1.00         1.00
# 22       Michigan         1.00         1.00
# 12          Idaho         0.93         1.00
# 19          Maine         0.95         0.99
# 13       Illinois         0.09         0.99
# 39   Rhode Island         0.71         0.97
# 9         Florida         0.83         0.97
# 29  New Hampshire         0.96         0.96

# %%
# ACT states participation rate between 2017 & 2018 in ascending manner
act_title = ['us_state','act_part_17','act_part_18']
final.sort_values('act_part_17', ascending=False)[act_title].head(18)
# Out:
#           us_state  act_part_17  act_part_18
# 0          Alabama         1.00         1.00
# 17        Kentucky         1.00         1.00
# 49       Wisconsin         1.00         1.00
# 44            Utah         1.00         1.00
# 42       Tennessee         1.00         1.00
# 40  South Carolina         1.00         1.00
# 36        Oklahoma         1.00         1.00
# 33  North Carolina         1.00         1.00
# 28          Nevada         1.00         1.00
# 26         Montana         1.00         1.00
# 24     Mississippi         1.00         1.00
# 23       Minnesota         1.00         0.99
# 18       Louisiana         1.00         1.00
# 25        Missouri         1.00         1.00
# 50         Wyoming         1.00         1.00
# 5         Colorado         1.00         0.30
# 3         Arkansas         1.00         1.00
# 34    North Dakota         0.98         0.98

# %%
# ACT states participation rate between 2017 & 2018 in ascending manner
act_title = ['us_state','act_part_17','act_part_18']
final.sort_values('act_part_18', ascending=False)[act_title].head(18)
# Out:
#           us_state  act_part_17  act_part_18
# 0          Alabama         1.00         1.00
# 17        Kentucky         1.00         1.00
# 49       Wisconsin         1.00         1.00
# 44            Utah         1.00         1.00
# 42       Tennessee         1.00         1.00
# 40  South Carolina         1.00         1.00
# 36        Oklahoma         1.00         1.00
# 35            Ohio         0.75         1.00
# 33  North Carolina         1.00         1.00
# 28          Nevada         1.00         1.00
# 27        Nebraska         0.84         1.00
# 26         Montana         1.00         1.00
# 24     Mississippi         1.00         1.00
# 18       Louisiana         1.00         1.00
# 25        Missouri         1.00         1.00
# 50         Wyoming         1.00         1.00
# 3         Arkansas         1.00         1.00
# 23       Minnesota         1.00         0.99

# %%
sat_title = ['us_state','sat_part_17','sat_part_18']
final[(final['sat_part_18']>0.9) & (final['sat_part_17']<0.5)][sat_title].head()
# Out:
#     us_state  sat_part_17  sat_part_18
# 5   Colorado         0.11         1.00
# 13  Illinois         0.09         0.99

# %%
sat_title = ['us_state','act_part_17','act_part_18']
final[(final['act_part_17']>0.9) & (final['act_part_18']<0.5)][sat_title].head()
# Out:
#     us_state  act_part_17  act_part_18
# 5   Colorado         1.00         0.30
# 13  Illinois         0.93         0.43

# %% [markdown]
# ### SAT
#
# |__US State__|__SAT 2017 Participation__|__SAT 2018 Participation__|__Rate Change__|
# |:---:|:---:|:---:|:---:|
# |Colorado |0.11 |1.00|*__809%__*
# |Illinois |0.09 |0.99|*__1,000%__*
#
# ### ACT
#
# |__US State__|__ACT 2017 Participation__|__ACT 2018 Participation__|__Rate Change__|
# |:---:|:---:|:---:|:---:|
# |Colorado|1.00 |0.30|*__-70%__*
# |Illinois |0.93 |0.43|*__-54%__*

# %% [markdown]
# From the rate change tables above, I have observed significant changes in Coloarado and Illinois between 2017 and 2018. The SAT partipication rate increased from around 10% to 99%, while the ACT participation rate has dropped more than 50%. These two states have drawn my attention beacuse of the changes and more research will be carried out to explore my interest.

# %% [markdown]
# ## US states that have more than 50% participation rate on both tests in 2017 and 2018

# %%
# participation rate of both test equal/ bigger than 50% in 2017
title_2017 = ['us_state','sat_part_17','act_part_17']
final[(final['sat_part_17']>0.5) & (final['act_part_17']>0.5)][title_2017].head()
# Out:
#    us_state  sat_part_17  act_part_17
# 9   Florida         0.83         0.73
# 10  Georgia         0.61         0.55
# 11   Hawaii         0.55         0.90

# %%
# participation rate of both test equal/ bigger than 50% in 2018
title_2018 = ['us_state','sat_part_18','act_part_18']
final[(final['sat_part_18']>0.5) & (final['act_part_18']>0.5)][title_2018].head()
# Out:
#           us_state  sat_part_18  act_part_18
# 9          Florida         0.97         0.66
# 10         Georgia         0.70         0.53
# 11          Hawaii         0.56         0.89
# 33  North Carolina         0.52         1.00
# 40  South Carolina         0.55         1.00

# %% [markdown]
# Based on the table above, Florida, Georgia and Hawaii are the only states with greater than 50% participation rates for both SAT and ACT test in 2017 and 2018.
# In my opinion, this happened because the participants want to increase their options to get into different colleges or hopefully scored a better mark on one or the other.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# generate correlation heatmap
mask = np.triu(final.corr())
fig, ax = plt.subplots(figsize=(16, 16))
ax = sns.heatmap(final.corr(), cmap='coolwarm',vmin=-1, vmax=1, square=True, linewidth=1,
                 annot=True,annot_kws={'size':'13'},cbar_kws={"shrink": 0.8},
                 mask=mask,fmt='.2g',center=0)
ax.set_title('Correlation Heatmap for SAT & ACT in 2017 & 2018', fontsize=22);

# %% [markdown]
# ### Correlation Observations
#
# From the heatmap above, I have noticed two interesting observations.
# - __Correlation between participation rate between SAT and ACT in 2017 and 2018__
#
#   The correlation between SAT and ACT is highly negative, -0.84 in 2017 and -0.85 in 2018. This number demonstates both of them are inverse correlations, which means the increase of a state's SAT participation rate will cause the decrease of the state's ACT participation rate, and vice versa.

# %% [markdown]
# - __Correlation between participation rate and subject mean score/ total/ composite in 2017 and 2018__
#
#   We can see the relationship between participation rate and the mean score has a highly negative correlation (more than -0.8), which means the lower participation relate will have higher subjects mean scores, total scores and composite scores. However, it could be a selection bias state-by-state because the participation rate varies across states. Additionally, the lower participation could be driven by highly motivated students or the students need to take the test to attend the college in another state. The higher participation rate could be impacted by the wider range of students' ability which may lead to lower mean score.

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
import matplotlib.mlab as mlab
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(15,10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column],color='darkorange', bins=20) # feel free to add more settings
        ax[i].set_title(list_of_titles[i],fontsize=16) # Set titles for each subplot
        ax[i].set_xlabel(list_of_xlabels[i],fontsize=13) # Set xlabel for each subplot
        ax[i].set_ylabel(list_of_ylabels[i],fontsize=13)
        ax[i].axvline(dataframe[column].mean(), label='Mean', color='g', linestyle='dashed', linewidth=2)
        ax[i].axvline(np.percentile(dataframe[column],25), label='25%', color='b', linestyle='dashed', linewidth=2)
        ax[i].axvline(np.percentile(dataframe[column],50), label='50%', color='r', linestyle='dashed', linewidth=2)
        ax[i].axvline(np.percentile(dataframe[column],75), label='75%', color='b', linestyle='dashed', linewidth=2)
        ax[i].legend()

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Participation rates for SAT & ACT
list_columns = ['sat_part_17','sat_part_18','act_part_17','act_part_18']
list_titles = ["SAT Participation Rate in 2017","SAT Participation Rate in 2018","ACT Participation Rate in 2017","ACT Participation Rate in 2018"]
subplot_histograms(final, list_columns, list_titles, ['Participation Rate(%)','Participation Rate(%)', 'Participation Rate(%)','Participation Rate(%)'], ['Frequency','Frequency','Frequency','Frequency'])
plt.tight_layout()

# %% [markdown]
# ### Participation Rates for SAT and ACT
#
# The histograms above show us the percentage of the participation of SAT and ACT in 2017 and 2018. It gives us a view of the changes from year to year. There are not many changes for either SAT and ACT test for both years.
#
# The SAT has a higher frequency for the state's participation rate at the lower end (less than 10%) while low frequency where the participation rate is more than 90%.
#
# However, the ACT shows the mirror result whereby it has a very high frequency for the state's participation rate more than 90% and relatively low frequency for the participation rate less than 10%.
#
# There are two different peaks which create the bimodal distribution and they are not normally distributed. The spread does not gather around the mean area, mostly around 1st and 3rd quartile where the bimodal distribution showed.

# %%
# Math scores for SAT & ACT
list_columns = ['sat_math_17','sat_math_18','act_math_17','act_math_18']
list_titles = ["SAT Math Mean Score in 2017","SAT Math Mean Score in 2018","ACT Math Mean Score in 2017","ACT Math Mean Score in 2018"]
subplot_histograms(final, list_columns, list_titles, ['Math Mean Score','Math Mean Score','Math Mean Score','Math Mean Score'], ['Frequency','Frequency','Frequency','Frequency'])
plt.tight_layout()

# %% [markdown]
# ### Math Scores for SAT and ACT
#
# There are not many changes for SAT and ACT math means score over the years.
#
# For the histograms above, there are 2 peaks/clusters which create the bimodal distribution and they are not normally distributed.

# %%
# Reading/verbal scores for SAT & ACT
list_columns = ['sat_erw_17','sat_erw_18','act_read_17','act_read_18']
list_titles = ["SAT Reading/Verbal Mean Score in 2017","SAT Reading/Verbal Mean Score in 2018","ACT Reading/Verbal Mean Score in 2017","ACT Reading/Verbal Mean Score in 2018"]
subplot_histograms(final, list_columns, list_titles, ['Reading/Verbal Mean Score','Reading/Verbal Mean Score','Reading/Verbal Mean Score','Reading/Verbal Mean Score'], ['Frequency','Frequency','Frequency','Frequency'])
plt.tight_layout()

# %% [markdown]
# ### Reading/ Verbal Scores for SAT & ACT
#
# There are many changes for SAT and ACT math means score over the years.
#
# For the histograms above, there are 2 peaks/clusters which create the bimodal distribution and they are not normally distributed.

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %% [markdown]
# ## Define the regression

# %%
def sns_lmplot(dataframe, x_axis, y_axis, title, x_label, y_label):
    sns.set_style('whitegrid')
    sns.lmplot(x=x_axis,y=y_axis,data=dataframe,height=7,scatter_kws={'color':'b','s':30},
               line_kws={"color":"darkorange","alpha":0.7,"lw":5})
    plt.title(title, fontsize=16)
    plt.xlabel(x_label, fontsize=13)
    plt.ylabel(y_label, fontsize=13)

# %%
# SAT vs. ACT math scores for 2017
sns_lmplot(final,'sat_math_17','act_math_17','SAT VS ACT Math Score for 2017',
            'SAT Math Mean Score', 'ACT Math Mean Score');

# %%
# SAT vs. ACT verbal/reading scores for 2017
sns_lmplot(final,'sat_erw_17','act_read_17','SAT VS ACT Verbal/Reading Score for 2017',
            'SAT Verbal/Reading Mean Score','ACT Verbal/Reading Mean Score');

# %%
# SAT vs. ACT total/composite scores for 2017
sns_lmplot(final,'sat_total_17','act_comp_17','SAT VS ACT Total/Composite Score for 2017',
            'SAT Total Mean Score','ACT Composite Mean Score');

# %% [markdown]
# For the comparions of SAT and ACT mean scores in term of Math, Verbal/Reading and Composite/Total, there are few points concentrated around the best fit line and most of the points are scattered throughout the chart. Thus, it is an unequal scatter, heteroscedasticity so the best fit line is not predictive. It is impossible to use the regression plot to prove that when a state has higher SAT mean score, it will have a lower ACT mean score and vise verse.

# %%
# Total scores for SAT 2017 vs. 2018
sns_lmplot(final,'sat_total_17','sat_total_18','SAT Total Score for 2017 vs 2018',
            'SAT Total Score 2017','SAT Total Score 2018');

# %% [markdown]
# For the scatter plot above, it shows that SAT total score between 2017 and 2018 have a positive linear relationship and there are some outliers. The results are generally consistent for most states over the 2 years.

# %%
# Composite scores for ACT 2017 vs. 2018
sns_lmplot(final,'act_comp_17','act_comp_18','ACT Composite Score for 2017 vs 2018',
            'ACT Composite Mean Score 2017','ACT Composite Mean Score 2018');

# %% [markdown]
# For the scatter plot above, it shows that ACT composite score between 2017 and 2018 have a positive linear relationship and there are some outliers. The results are generally consistent over the 2 years.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Boxplots for SAT and ACT participation rate in 2017 and 2018
participation_data = final[['sat_part_17','sat_part_18', 'act_part_17','act_part_18']]
plt.figure(figsize=(12,6))
sns.set_context("notebook", font_scale=1.2)
sns.boxplot(data=participation_data,orient='h',fliersize=8,linewidth=0.25, saturation=1.0, notch=True)
sns.swarmplot(data=participation_data, color=".25",orient='h')
plt.title('The Distribution of SAT and ACT participation rate in 2017 and 2018', fontsize=16)
plt.xlabel('Participation Rate(%)')
plt.yticks(np.arange(4),labels = ['SAT 2017', 'SAT 2018', 'ACT 2017', 'ACT 2018']);

# %% [markdown]
# From the boxplot above, you can see that the SAT has a higher concentration at the lower end while the ACT has higher concentration at the upper end. These results tell us that the ACT has higher participation rate compared to the SAT. There is no visible outlier and the data set is not symmetrical.

# %%
# Boxplots for SAT subject test mean score in 2017 and 2018
sat_data = final[['sat_erw_17','sat_erw_18','sat_math_17','sat_math_18']]
plt.figure(figsize=(12,6))
sns.set_context("notebook", font_scale=1.2)
sns.boxplot(data=sat_data, orient='h',fliersize=8,linewidth=0.25, saturation=1.0, notch=True)
sns.swarmplot(data=sat_data, color=".25",orient='h')
plt.title('SAT Subject Test Mean Score in 2017 and 2018', fontsize=16)
plt.xlabel('Mean Score')
plt.yticks(np.arange(4),labels = ['SAT ERW 2017', 'SAT ERW 2018', 'SAT Math 2017', 'SAT Math 2018']);

# %%
# Boxplots for SAT total score in 2017 and 2018
sat_data_total = final[['sat_total_17','sat_total_18']]
plt.figure(figsize=(12,3))
sns.set_context("notebook", font_scale=1.2)
sns.boxplot(data=sat_data_total, orient='h',fliersize=8,linewidth=0.25, saturation=1.0, notch=True)
sns.swarmplot(data=sat_data_total, color=".25",orient='h')
plt.title('SAT Total Score in 2017 and 2018', fontsize=16)
plt.xlabel('Total Score')
plt.yticks(np.arange(2),labels = ['SAT 2017', 'SAT 2018']);

# %% [markdown]
# From the boxplots above, the results for the SAT subjects' mean scores and total score are similar but not the same for both years. There is no visible outlier and the data set is not symmetrical.

# %%
# Boxplots for ACT subject test and composite mean score in 2017 and 2018
act_data = final[['act_eng_17','act_eng_18','act_math_17','act_math_18',
                  'act_read_17','act_read_18','act_sci_17','act_sci_18',
                  'act_comp_17','act_comp_18']]
plt.figure(figsize=(12,8))
sns.set_context("notebook", font_scale=1.2)
sns.boxplot(data=act_data, orient='h',fliersize=8,linewidth=0.25, saturation=1.0, notch=True)
sns.swarmplot(data=act_data, color=".25",orient='h')
plt.title('ACT Subject Test, Composite Mean Score in 2017 and 2018', fontsize=16)
plt.xlabel('Mean Score')
plt.yticks(np.arange(10),labels = ['ACT English 2017','ACT English 2018','ACT Math 2017','ACT Math 2018',
                                   'ACT Read 2017','ACT Read 2018','ACT Science 2017','ACT Science 2018',
                                   'ACT Composite 2017','ACT Composite 2018']);

# %% [markdown]
# From the boxplots above, the results for most of the ACT subjects' mean scores and total score are similar but not the same for both years. There is no visible outlier and the data set is not symmetrical.
#
# For ACT composite mean score, the IQR in 2017 and larger than the 2018, which mean mean score in 2017 is more broadly spread than 2018.

# %%
# normalized the data to generate 1 boxplot
final_norm = pd.DataFrame([(final[i]-final[i].min())/(final[i].max()-final[i].min()) for i in final.columns[1:]]).T
final_norm.head()
# Out:
#    sat_part_17  sat_erw_17  sat_math_17  sat_total_17  act_part_17  \
# 0     0.030612    0.685185     0.568306      0.623188     1.000000
# 1     0.367347    0.401235     0.355191      0.376812     0.619565
# 2     0.285714    0.500000     0.464481      0.481159     0.586957
# 3     0.010204    0.814815     0.688525      0.747826     1.000000
# 4     0.520408    0.302469     0.306011      0.304348     0.250000
#
#    act_eng_17  act_math_17  act_read_17  act_sci_17  act_comp_17  sat_part_18  \
# 0    0.282609     0.054795     0.202532    0.179104     0.181818     0.040816
# 1    0.260870     0.246575     0.291139    0.253731     0.259740     0.418367
# 2    0.250000     0.246575     0.253165    0.238806     0.246753     0.275510
# 3    0.282609     0.136986     0.202532    0.194030     0.207792     0.030612
# 4    0.673913     0.643836     0.632911    0.597015     0.649351     0.591837
#
#    sat_erw_18  sat_math_18  sat_total_18  act_part_18  act_eng_18  \
# ...

# %%
# normalized the data and created a boxplot for all data
plt.figure(figsize=(12,20))
sns.set_context("notebook", font_scale=1.2)
sns.boxplot(data=final_norm, orient='h',fliersize=8,linewidth=0.25, saturation=1.0, notch=True)
sns.swarmplot(data=final_norm, color=".25",orient='h')
plt.title('Normalized Data for SAT and ACT in 2017 and 2018', fontsize=16);

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
plt.figure(figsize=(12,8))
sns.distplot(final['sat_part_17'], kde=True, label='SAT Participation 2017', bins = 20)
sns.distplot(final['act_part_17'], kde=True, label='ACT Participation 2017', bins = 20)
plt.legend(prop={'size': 12})
plt.title('Participation Rate in 2017')
plt.xlabel('Participation rate (%)')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(12,8))
sns.distplot(final['sat_part_18'], kde=True, label='SAT Participation 2018', bins = 20)
sns.distplot(final['act_part_18'], kde=True, label='ACT Participation 2018', bins = 20)
plt.legend(prop={'size': 12})
plt.title('Participation Rate in 2018')
plt.xlabel('Participation rate (%)')
plt.ylabel('Frequency');

# %% [markdown]
# I used overlay histogram to find the difference between SAT and ACT participation rate for both years.
#
# The SAT has a higher frequency for the state's participation rate at the lower end (less than 10%) while low frequency where the participation rate is more than 90%.
#
# However, the ACT shows the mirror result whereby it has a very high frequency for the state's participation rate more than 90% and relatively low frequecy for the participation rate less than 10%.

# %%
sns.jointplot(x='sat_part_17',y='act_part_17',data=final,kind='reg',
              marginal_kws={'color':'orange', 'bins':20},
              line_kws={'color':'darkorange'},
              scatter_kws={'color':'blue'},dropna=True,height=10, space=0.3, ratio=5)
plt.title('SAT and ACT Participation Rate in 2017');

# %% [markdown]
# The jointplot above shows the histograms and scatter plot with regression line. Neither histograms is normally distributed and both displyed bimodal distributed characteristics. The scatter plot shows that there is an inverse correlation whereby increment of one participation rate will lead to decrement of the other participation rate.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# <img src="SAT Participation Rate in Year 2017.JPG">
# <img src="SAT Participation Rate in Year 2018.JPG">
# <img src="ACT Participation Rate in Year 2017.JPG">
# <img src="ACT Participation Rate in Year 2018.JPG">

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
f, axes = plt.subplots(2, 2, figsize=(14, 10))
sns.despine(left=True)

plt.subplot(221)
plt.title("Act English Mean Score in 2017", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['act_eng_17'],axlabel="Mean Score",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.subplot(222)
plt.title("ACT English Mean Score in 2018", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['act_eng_18'],axlabel="Mean Score",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.subplot(223)
plt.title("ACT Science Mean Score in 2017", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['act_sci_17'],axlabel="Mean Score",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.subplot(224)
plt.title("ACT Science Mean Score in 2018", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['act_sci_18'],axlabel="Mean Score",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.tight_layout()

# %%
f, axes = plt.subplots(2, 2, figsize=(14, 10))
sns.despine(left=True)

plt.subplot(221)
plt.title("SAT Total Score in 2017", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['sat_total_17'],axlabel="Participation Rate(%)",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.subplot(222)
plt.title("SAT Total Score in 2018", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['sat_total_18'],axlabel="Participation Rate(%)",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.subplot(223)
plt.title("ACT Composite Score in 2017", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['act_comp_17'],axlabel="Participation Rate(%)",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.subplot(224)
plt.title("ACT Composite Score in 2018", fontsize=16)
plt.ylabel('Density')
sns.distplot(final['act_comp_18'],axlabel="Participation Rate(%)",bins=20,color='blue',kde_kws={'color':'darkorange'})

plt.tight_layout()

# %% [markdown]
# |__Features__|__Description__|
# |:--|--:|
# |sat_part_17 |It is a non normal distribution. The spread is not concentrated around the mean area, mostly around 1st and 3rd quartile where the bimodal distribuation is exhibited.|
# |sat_erw_17 |It is bimodal distribuation and a non normal distribution|
# |sat_math_17 |It is bimodal distribuation and a non normal distribution|
# |sat_total_17 |It is bimodal distribuation and a non normal distribution|
# |act_part_17 |It is a non normal distribution. The spread is not concentrated around the mean area, mostly around 1st and 3rd quartile where the bimodal distribuation is exhibited.|
# |act_eng_17  |It is bimodal distribuation and a non normal distribution|
# |act_math_17 |It is bimodal distribuation and a non normal distribution|
# |act_read_17 |It is bimodal distribuation and a non normal distribution|
# |act_sci_17 |It is bimodal distribuation and a non normal distribution|
# |act_comp_17 |It is bimodal distribuation and a non normal distribution|
# |sat_part_18 |It is a non normal distribution. The spread is not concentrated around the mean area, mostly around 1st and 3rd quartile where the bimodal distribuation is exhibited.|
# |sat_erw_18 |It is bimodal distribuation and a non normal distribution|
# |sat_math_18 |It is bimodal distribuation and a non normal distribution|
# |sat_total_18 |It is bimodal distribuation and a non normal distribution|
# |act_part_18 |It is a non normal distribution. The spread is not concentrated around the mean area, mostly around 1st and 3rd quartile where the bimodal distribuation is exhibited.|
# |act_eng_18  |It is bimodal distribuation and a non normal distribution|
# |act_math_18 |It is bimodal distribuation and a non normal distribution|
# |act_read_18 |It is bimodal distribuation and a non normal distribution|
# |act_sci_18 |It is bimodal distribuation and a non normal distribution|
# |act_comp_18 |It is bimodal distribuation and a non normal distribution|

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# The CLT tells us that when the sample size is increased, the distributions of the sample means will tend toward a normal distribution, even though the distribution of the population is not normally distributed. But, the data does not have the correct information to apply to CLT theorem.
#
# We have to consider the number of the participants of each states instead of the participation rate(%) because it could affect the state's means score(sample). The participation rate varies from 0% to 100% across the states. The mean score for each state with a high participation rate should not be considered as similar to the state with a low participation rate, even if we use the same sample size across each state to get the sample mean.
#
# Thus, in order to apply CLT theorem, it is strongly recommended to use the sample from the population(nation-wide). We should avoid using the state's mean results even though the number of participants of each state is equal because it could bias state's result.
#
# One cannot see the normal distribution trend just by looking at the data. We should generate the histogram to observe the trend.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# For the data above, because the number of participants across the states varies which will affect the means score for both Math and Reading . Thus the sample would not be suitable to apply into CLT theorem. The same applies to the data of participation rate across the states.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Since our sample of the participation rate is in percentage, and the amount of the participation across the states varies, the sample will not be consistent. And it is not suitable to apply to the CLT theorem to generate the normal distribution. If we are unable to get the normal distribution, we will not able to do the statistical inference.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Let's take the sample in 2018, SAT Math mean score 557.25 while ACT Math mean score is 21.13. Hypothetically given that SAT and ACT Math test is at the same level, we can normalize both mean score so that we will able to compare the students' performance for both SAT and ACT math scores.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# ### Example of Hypothesis Testing: SAT participation rate vs ACT participation rate

# %%
from scipy import stats

# %%
sat_part_17 = final['sat_part_17']
act_part_17 = final['act_part_17']

# %%
display(len(sat_part_17))
display(len(act_part_17))
# Out:
# 51
# 51

# %%
display(sat_part_17.mean())
display(act_part_17.mean())
# Out:
# 0.39803921568627454
# 0.6525490196078431

# %%
sat_part_17.mean() - act_part_17.mean()
# Out:
# -0.2545098039215685

# %%
display(sat_part_17.var())
display(act_part_17.var())
# Out:
# 0.12444407843137252
# 0.10330337254901964

# %%
stats.ttest_ind(sat_part_17, act_part_17, equal_var=False)
# Out:
# Ttest_indResult(statistic=-3.8085778908170544, pvalue=0.00024238408285306838)

# %%
t_stat, p_value = stats.ttest_ind(sat_part_17, act_part_17, equal_var=False)
p_value
# Out:
# 0.00024238408285306838

# %% [markdown]
# The p-value is less than 0.05, thus there is evidence to reject the null hypothesis. SAT participation rate is not equal to ACT participation rate.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %%
display(final[(final['sat_part_17']<0.5) & (final['sat_part_18']>0.9)][['us_state','sat_part_17','sat_part_18']])
display(final[(final['act_part_17']>0.9) & (final['act_part_18']<0.5)][['us_state','act_part_17','act_part_18']])
display(final[(final['sat_part_18']<0.5) & (final['act_part_18']<0.5)][['us_state','sat_part_18','act_part_18']])
display(final[final['us_state']=='Alaska'][['us_state','sat_part_17','act_part_17','sat_part_18','act_part_18']])
# Out:
#     us_state  sat_part_17  sat_part_18
# 5   Colorado         0.11         1.00
# 13  Illinois         0.09         0.99
#     us_state  act_part_17  act_part_18
# 5   Colorado         1.00         0.30
# 13  Illinois         0.93         0.43
#    us_state  sat_part_18  act_part_18
# 1    Alaska         0.43         0.33
# 37   Oregon         0.48         0.42
#   us_state  sat_part_17  act_part_17  sat_part_18  act_part_18
# 1   Alaska         0.38         0.65         0.43         0.33

# %% [markdown]
# I noticed many interesting changes in a number of states in terms of SAT and ACT participation rates. 2 states in particular caught my attention.
#
# First we look at ACT participation rate for __Colorado__ in 2017 and 2018. You can see the participation rate increased from 11% to 100%, which is 809% increment. While at the same time, the ACT participation rate has decreased from 100% to 30%. Such significant changes prompted me to search for an explanation. In 2017, the state authority switched from mandatory ACT to mandatory SAT testing which explained the changes. The core reason for the switch was that state officials deemed the SAT test to be more closely aligned to the state's academic standard.
#
# Now we will look at participation rate for __Illinois__ in 2017 and 2018. The participation rate for the SAT has increased by 1,000%, which is a huge increment meanwhile the ACT decreased by 54%. I discovered that state switched from mandatory ACT to mandatory SAT test. The Illinois State Board of Education (ISBE) claimed that SAT test is better aligned with the state's academic standard. Thus, ISBE has made SAT test mandatory for high school graduates.
#
# Another inconsistency I observed was in __Alaska__. Alaska shows different result of participation rate whereby the sum of SAT and ACT test participation rate in 2018 is less than 76% considreing students taking both tests. In 2017, the Alaska Legislature relaxed the previous requirement that required students to take only SAT or ACT and provided the option to take the workKeys test as well for admission evaluation. You can see the participation rate for ACT in 2018 has decreased by 49% while SAT increased by 13%.
#
# __References:__
# - [Testive: Colorado Changed to the SAT in 2017](https://www.testive.com/colorado-sat-change-2017/#:~:text=On%20April%2011th%2C%202017%20all,a%20new%20four%20hour%20exam.)
# - [Chalkbeat](https://co.chalkbeat.org/2017/8/17/21100853/sat-scores-show-mixed-results-on-whether-colorado-juniors-are-on-track-for-college)
# - [Illinois moves ahead with new testing plan, replacing ACT with SAT](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# - [Alaska high school students no longer need national tests to graduate](https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/)

# %% [markdown]
# # Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %%
display(final[final['us_state']=='Iowa'][['us_state','sat_part_17','act_part_17','sat_part_18','act_part_18']])
display(final[final['us_state']=='Iowa'][['us_state','sat_total_17','act_comp_17','sat_total_18','act_comp_18']])
# Out:
#    us_state  sat_part_17  act_part_17  sat_part_18  act_part_18
# 15     Iowa         0.02         0.67         0.03         0.68
#    us_state  sat_total_17  act_comp_17  sat_total_18  act_comp_18
# 15     Iowa          1275         21.9          1265         21.8

# %% [markdown]
# Based on my data exploration and outside research, the participation on either of the test is mainly influenced by state authorities. A small portion of the participation rate came from the individual preference. In the US, 18 states have mandated the ACT test and 11 states have mandated the SAT test while the rest of the states have no restriction on the choice of college entrance test.
#
# Let's consider __Iowa__ as it only has less than 4% of the SAT participation rate in 2017 and 2018. Iowa has not made any test mandatory and all students can go with their preference. In order to the boost the SAT participation rate in Iowa, the College Board should consider to revamp and improve the SAT test so that it aligns with Iowa education standard and propose to state authority.
#
# There are 2 broad approaches to driving change- the __Carrot__ and the __Stick__. The Carrot relies on incentives while the Stick is more directive.
#
# __Carrot:__ The College Board should consider providing additional subsidies to the state authority to help the state support the participants from low income families. Besides that, College Board should consider offering free tuition classes, either remotely or on campus to help the students prepare for the SAT test. This is because the sudden switch of test might lead to large changes to average scores if the high schools' curriculum is no aligned to the test or the students are not prepared for the SAT test. This happened in Colorado and Illinois. College Board should also introduce SAT school day on a weekday to allow students to be in a familiar setting or fee waiver benefits for low-income students.
#
# __Stick:__ The Iowa Department of Education should consider making SAT test mandatory as the college admission requirement which provides benefits to the education system and the students. High schools will make sure all the subjects are covered and educate the students with the proper method and mindset to tackle SAT test. Besides that, the SAT test can be used to benchmark students and to analyse the high-school education system.
#
# In conclusion, the project analyzed SAT and ACT participation rates and their respective scores in 2017 and 2018. Although SAT participation rates have some improvement in certain states, the ACT still has a stronghold in many states which most states require students to take ACT. The College Board should target the states with lower participation rates and adopt the solutions recommended above.
#
# Overall, from my perspective, all state authorities should consider encouraging participants to take more than one test in order to give themselves more opportunities to apply for colleges in other states. Further research should be carried out on how to encourage the participants to take more than one test and show the participants the benefits of taking more than one test. The College Board should target the states with low participation rates. College could adopt the above recommendations.
#
# In addition, I hope I have demonstrated in a number of instances above that the states' participation rate is not the ideal benchmark for comparison due to the different number of participants in each state. The sample should be drawn from the population randomly to make the analysis more comparable.
#
# __References:__
# - [Does your state require the SAT or ACT?](https://www.testive.com/state-sat-act/)
